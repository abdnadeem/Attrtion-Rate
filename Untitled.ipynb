# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv('Train.csv')

# %%
df1 = pd.read_csv('Test.csv')

# %%
df
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_23371      F  42.0                4             Married
# 1      EID_18000      M  24.0                3              Single
# 2       EID_3891      F  58.0                3             Married
# 3      EID_17492      F  26.0                3              Single
# 4      EID_22534      F  31.0                1             Married
# 5       EID_2278      M  54.0                3             Married
# 6      EID_18588      F  21.0                4             Married
# 7       EID_1235      F   NaN                3             Married
# 8      EID_10197      M  40.0                4              Single
# 9      EID_21262      M  45.0                3             Married
# 10      EID_9153      F  65.0                5              Single
# 11     EID_19087      F  19.0                5              Single
# 12      EID_4825      M  63.0                3             Married
# ...

# %%
np.mean(df['Age'])
# Out:
# 39.62279902853673

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
enc = LabelEncoder()
ohc = OneHotEncoder()

# %%
df['Gender'] = enc.fit_transform(df['Gender'])

# %%
df
# Out:
#      Employee_ID  Gender   Age  Education_Level Relationship_Status  \
# 0      EID_23371       0  42.0                4             Married
# 1      EID_18000       1  24.0                3              Single
# 2       EID_3891       0  58.0                3             Married
# 3      EID_17492       0  26.0                3              Single
# 4      EID_22534       0  31.0                1             Married
# 5       EID_2278       1  54.0                3             Married
# 6      EID_18588       0  21.0                4             Married
# 7       EID_1235       0   NaN                3             Married
# 8      EID_10197       1  40.0                4              Single
# 9      EID_21262       1  45.0                3             Married
# 10      EID_9153       0  65.0                5              Single
# 11     EID_19087       0  19.0                5              Single
# 12      EID_4825       1  63.0                3             Married
# ...

# %%
df['Relationship_Status'] = enc.fit_transform(df['Relationship_Status'])

# %%
df['Compensation_and_Benefits'] = enc.fit_transform(df['Compensation_and_Benefits'])

# %%
df
# Out:
#      Employee_ID  Gender   Age  Education_Level  Relationship_Status  \
# 0      EID_23371       0  42.0                4                    0
# 1      EID_18000       1  24.0                3                    1
# 2       EID_3891       0  58.0                3                    0
# 3      EID_17492       0  26.0                3                    1
# 4      EID_22534       0  31.0                1                    0
# 5       EID_2278       1  54.0                3                    0
# 6      EID_18588       0  21.0                4                    0
# 7       EID_1235       0   NaN                3                    0
# 8      EID_10197       1  40.0                4                    1
# 9      EID_21262       1  45.0                3                    0
# 10      EID_9153       0  65.0                5                    1
# 11     EID_19087       0  19.0                5                    1
# 12      EID_4825       1  63.0                3                    0
# ...

# %%
df['Decision_skill_possess'] = enc.fit_transform(df['Decision_skill_possess'])

# %%
df = df[df.columns[df.isnull().mean() <0.7 ]]
df = df.loc[df.isnull().mean(axis = 1) < 0.7]

# %%
df['Age'] = df['Age'].fillna(39)

# %%
df = df.fillna(0)

# %%
X = df[['Work_Life_balance','Pay_Scale','Travel_Rate','Compensation_and_Benefits', 'Time_since_promotion']].astype(float)

# %%
np.mean(df1['Age'])
# Out:
# 39.797816132441

# %%
Y = df['Attrition_rate'].astype(float)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
model.fit(X, Y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
df1 = df1[df1.columns[df1.isnull().mean() <0.7 ]]
df1 = df1.loc[df1.isnull().mean(axis = 1) < 0.7]
df1['Age'] = df['Age'].fillna(39)
df1 = df1.fillna(0)

# %%
df1['Compensation_and_Benefits'] = enc.fit_transform(df1['Compensation_and_Benefits'])

# %%
X_test = df1[['Work_Life_balance','Pay_Scale','Travel_Rate','Compensation_and_Benefits', 'Time_since_promotion']].astype(float)

# %%
pred = model.predict(X_test)

# %%
Employee = df1['Employee_ID']

# %%
data = {'Employee_ID' : Employee,
        'Attrition_rate' : pred
    
    
}

# %%
df3 = pd.DataFrame(data, columns = ['Employee_ID' ,'Attrition_rate'])

# %%
df3
# Out:
#      Employee_ID  Attrition_rate
# 0      EID_22713        0.221978
# 1       EID_9658        0.139017
# 2      EID_22203        0.230807
# 3       EID_7652        0.126555
# 4       EID_6516        0.040054
# 5      EID_20283        0.208473
# 6      EID_21014        0.221978
# 7       EID_7693        0.198833
# 8      EID_13232        0.205831
# 9       EID_6515        0.089601
# 10     EID_13639        0.147875
# 11     EID_14669        0.155063
# 12     EID_16537        0.085597
# 13      EID_5782        0.206722
# 14     EID_20157        0.131598
# 15      EID_1855        0.134607
# 16     EID_20748        0.205422
# 17     EID_23179        0.235293
# 18     EID_12838        0.159991
# 19     EID_21656        0.160631
# 20      EID_8844        0.129331
# 21      EID_1536        0.122416
# 22      EID_8822        0.130567
# 23     EID_11398        0.173651
# 24     EID_12965        0.240666
# 25      EID_5204        0.091711
# 26     EID_10030        0.236230
# ...

# %%
 df3.to_csv('Sub.csv', index = False)

# %%
df4 = pd.read_csv('sample_submission.csv')

# %%
df4
# Out:
#   Employee_ID  Attrition_rate
# 0       TID_1          0.1588
# 1       TID_2          0.1424
# 2       TID_3          0.4758
# 3       TID_4          0.0846
# 4       TID_5          0.2388
